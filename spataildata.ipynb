# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
#BANGLORE MAP WITH FAMOUS PLACES INCLUDING IMAGES
# Latitude and longitude coordinates of Bangalore
bangalore_coords = (12.9716, 77.5946)

# Create a map centered around Bangalore
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)

# Define famous places and their coordinates in Bangalore

places = {
    "Lalbagh Botanical Garden": (12.9507, 77.5844),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Kempegowda International Airport": (13.192665896, 77.70333052)
}



# Define images for each place
images = {
    "Lalbagh Botanical Garden": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&h=1200&s=1",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Kempegowda International Airport": "https://tse4.mm.bing.net/th?id=OIP.tu4IQk62ZmQfQhbIPDfZ8AHaE8&pid=Api&P=0&h=180"
}

# Add markers for each place
for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

# Display the map
map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aab60fda4d1357b989a6df06b4e74a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aab60fda4d1357b989a6df06b4e74a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aab60fda4d1357b989a6df06b4e74a7 = L.map(
#                 &quot;map_8aab60fda4d1357b989a6df06b4e74a7&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_355f0aac0ced0ae46ece51de9a2cb09c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#             var marker_62222d8562252943791c00a9cb8d2c8d = L.marker(
#                 [12.9507, 77.5844],
#                 {}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#         var popup_0225afecdf206b6fb5afb492f2878ed4 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_0a550b45380e0b836dafd234aed16345 = $(`&lt;div id=&quot;html_0a550b45380e0b836dafd234aed16345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lalbagh Botanical Garden&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&amp;h=1200&amp;s=1&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_0225afecdf206b6fb5afb492f2878ed4.setContent(html_0a550b45380e0b836dafd234aed16345);
#
#
#
#         marker_62222d8562252943791c00a9cb8d2c8d.bindPopup(popup_0225afecdf206b6fb5afb492f2878ed4)
#         ;
#
#
#
#
#             var marker_8e23db2f1a039c5543004bab6308f658 = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#         var popup_22df0237e88c59d0334444cecea68343 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_dda1b2d8f3729f7f93093665704553c2 = $(`&lt;div id=&quot;html_dda1b2d8f3729f7f93093665704553c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_22df0237e88c59d0334444cecea68343.setContent(html_dda1b2d8f3729f7f93093665704553c2);
#
#
#
#         marker_8e23db2f1a039c5543004bab6308f658.bindPopup(popup_22df0237e88c59d0334444cecea68343)
#         ;
#
#
#
#
#             var marker_37367dabe2085e8d5a4244458fbecfad = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#         var popup_4a54f85c52641fddf6b40aa950f8e093 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_1f3842c500d96f794266e567cfe60627 = $(`&lt;div id=&quot;html_1f3842c500d96f794266e567cfe60627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_4a54f85c52641fddf6b40aa950f8e093.setContent(html_1f3842c500d96f794266e567cfe60627);
#
#
#
#         marker_37367dabe2085e8d5a4244458fbecfad.bindPopup(popup_4a54f85c52641fddf6b40aa950f8e093)
#         ;
#
#
#
#
#             var marker_54c440e903a602c1b342c41a0d98efef = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#         var popup_17f305b29d9ee50e4e8de516bdb194a1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_7e8130212531cdc91cee5e7af2be3bbd = $(`&lt;div id=&quot;html_7e8130212531cdc91cee5e7af2be3bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vidhana Soudha&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_17f305b29d9ee50e4e8de516bdb194a1.setContent(html_7e8130212531cdc91cee5e7af2be3bbd);
#
#
#
#         marker_54c440e903a602c1b342c41a0d98efef.bindPopup(popup_17f305b29d9ee50e4e8de516bdb194a1)
#         ;
#
#
#
#
#             var marker_2615c684ca73c4e659bb47f9265e0745 = L.marker(
#                 [13.1682, 77.5354],
#                 {}
#             ).addTo(map_8aab60fda4d1357b989a6df06b4e74a7);
#
#
#         var popup_7603b25ef13013308277f4b1f2495d3d = L.popup({&
